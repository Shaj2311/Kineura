# %%
import torch
import torch.nn as nn

class VideoEnhancementModel(nn.Module):
    def __init__(self):
        super(VideoEnhancementModel, self).__init__()
        
        # 6 channels in (2 frames) -> 16 out
        self.conv1 = nn.Conv2d(in_channels=6, out_channels=16, kernel_size=3, padding=1)
        self.relu1 = nn.ReLU()
        
        # keep it at 16 for a bit to process
        self.conv2 = nn.Conv2d(in_channels=16, out_channels=16, kernel_size=3, padding=1)
        self.relu2 = nn.ReLU()
        
        # compress back down to 3 channels (1 frame)
        self.conv3 = nn.Conv2d(in_channels=16, out_channels=3, kernel_size=3, padding=1)
        
    def forward(self, x):
        x = self.conv1(x)
        x = self.relu1(x)
        
        x = self.conv2(x)
        x = self.relu2(x)
        
        modelOutput = self.conv3(x) 
        
        return modelOutput

# test block to make sure the math works
if __name__ == "__main__":
    dummyInput = torch.randn(4, 6, 256, 256)
    
    enhancementModel = VideoEnhancementModel()
    dummyOutput = enhancementModel(dummyInput)
    
    print("test successful!")
    print(f"input shape:  {dummyInput.shape}")
    print(f"output shape: {dummyOutput.shape}")
# Out:
# test successful!
# input shape:  torch.Size([4, 6, 256, 256])
# output shape: torch.Size([4, 3, 256, 256])
